# %% [markdown]
# # Exploring Table Data: 2014-15 NBA Shot Log
#
# Erik Gabrielsen, Danh Nguyen

# %% [markdown]
# ## Business Understanding

# %% [markdown]
# ## Data Understanding
#
# The original data set is displayed below.

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('~/Downloads/shot_logs.csv') # read in the csv file

df.head()
# Out:
#     GAME_ID                   MATCHUP LOCATION  W  FINAL_MARGIN  SHOT_NUMBER  \
# 0  21400899  MAR 04, 2015 - CHA @ BKN        A  W            24            1
# 1  21400899  MAR 04, 2015 - CHA @ BKN        A  W            24            2
# 2  21400899  MAR 04, 2015 - CHA @ BKN        A  W            24            3
# 3  21400899  MAR 04, 2015 - CHA @ BKN        A  W            24            4
# 4  21400899  MAR 04, 2015 - CHA @ BKN        A  W            24            5
#
#    PERIOD GAME_CLOCK  SHOT_CLOCK  DRIBBLES    ...     SHOT_DIST  PTS_TYPE  \
# 0       1       1:09        10.8         2    ...           7.7         2
# 1       1       0:14         3.4         0    ...          28.2         3
# 2       1       0:00         NaN         3    ...          10.1         2
# 3       2      11:47        10.3         2    ...          17.2         2
# 4       2      10:34        10.9         2    ...           3.7         2
#
#    SHOT_RESULT   CLOSEST_DEFENDER CLOSEST_DEFENDER_PLAYER_ID  CLOSE_DEF_DIST  \
# 0         made     Anderson, Alan                     101187             1.3
# 1       missed  Bogdanovic, Bojan                     202711             6.1
# 2       missed  Bogdanovic, Bojan                     202711             0.9
# 3       missed      Brown, Markel                     203900             3.4
# 4       missed    Young, Thaddeus                     201152             1.1
#
#    FGM  PTS    player_name player_id
# 0    1    2  brian roberts    203148
# 1    0    0  brian roberts    203148
# 2    0    0  brian roberts    203148
# 3    0    0  brian roberts    203148
# 4    0    0  brian roberts    203148
#
# [5 rows x 21 columns]

# %%
df.head()
# Out:
#     GAME_ID                   MATCHUP LOCATION  W  FINAL_MARGIN  SHOT_NUMBER  \
# 0  21400899  MAR 04, 2015 - CHA @ BKN        A  W            24            1
# 1  21400899  MAR 04, 2015 - CHA @ BKN        A  W            24            2
# 2  21400899  MAR 04, 2015 - CHA @ BKN        A  W            24            3
# 3  21400899  MAR 04, 2015 - CHA @ BKN        A  W            24            4
# 4  21400899  MAR 04, 2015 - CHA @ BKN        A  W            24            5
#
#    PERIOD GAME_CLOCK  SHOT_CLOCK  DRIBBLES    ...     SHOT_DIST  PTS_TYPE  \
# 0       1       1:09        10.8         2    ...           7.7         2
# 1       1       0:14         3.4         0    ...          28.2         3
# 2       1       0:00         NaN         3    ...          10.1         2
# 3       2      11:47        10.3         2    ...          17.2         2
# 4       2      10:34        10.9         2    ...           3.7         2
#
#    SHOT_RESULT   CLOSEST_DEFENDER CLOSEST_DEFENDER_PLAYER_ID  CLOSE_DEF_DIST  \
# 0         made     Anderson, Alan                     101187             1.3
# 1       missed  Bogdanovic, Bojan                     202711             6.1
# 2       missed  Bogdanovic, Bojan                     202711             0.9
# 3       missed      Brown, Markel                     203900             3.4
# 4       missed    Young, Thaddeus                     201152             1.1
#
#    FGM  PTS    player_name player_id
# 0    1    2  brian roberts    203148
# 1    0    0  brian roberts    203148
# 2    0    0  brian roberts    203148
# 3    0    0  brian roberts    203148
# 4    0    0  brian roberts    203148
#
# [5 rows x 21 columns]

# %%
df.describe()
# Out:
# /Users/danh/anaconda/envs/machinelearning/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#             GAME_ID   FINAL_MARGIN    SHOT_NUMBER         PERIOD  \
# count  1.280690e+05  128069.000000  128069.000000  128069.000000
# mean   2.140045e+07       0.208723       6.506899       2.469427
# std    2.578773e+02      13.233267       4.713260       1.139919
# min    2.140000e+07     -53.000000       1.000000       1.000000
# 25%    2.140023e+07      -8.000000       3.000000       1.000000
# 50%    2.140045e+07       1.000000       5.000000       2.000000
# 75%    2.140067e+07       9.000000       9.000000       3.000000
# max    2.140091e+07      53.000000      38.000000       7.000000
#
#           SHOT_CLOCK       DRIBBLES     TOUCH_TIME      SHOT_DIST  \
# count  122502.000000  128069.000000  128069.000000  128069.000000
# mean       12.453344       2.023355       2.765901      13.571504
# std         5.763265       3.477760       3.043682       8.888964
# min         0.000000       0.000000    -163.600000       0.000000
# 25%              NaN       0.000000       0.900000       4.700000
# 50%              NaN       1.000000       1.600000      13.700000
# 75%              NaN       2.000000       3.700000      22.500000
# max        24.000000      32.000000      24.900000      47.200000
#
#             PTS_TYPE  CLOSEST_DEFENDER_PLAYER_ID  CLOSE_DEF_DIST  \
# count  128069.000000               128069.000000   128069.000000
# mean        2.264670               159038.487284        4.123015
# std         0.441159                78791.172947        2.756446
# min         2.000000                  708.000000        0.000000
# 25%         2.000000               101249.000000        2.300000
# 50%         2.000000               201949.000000        3.700000
# 75%         3.000000               203079.000000        5.300000
# max         3.000000               530027.000000       53.200000
#
#                  FGM            PTS      player_id
# count  128069.000000  128069.000000  128069.000000
# mean        0.452139       0.997314  157238.251247
# std         0.497706       1.130978   79362.389336
# min         0.000000       0.000000     708.000000
# 25%         0.000000       0.000000  101162.000000
# 50%         0.000000       0.000000  201939.000000
# 75%         1.000000       2.000000  202704.000000
# max         1.000000       3.000000  204060.000000

# %% [markdown]
# ### Data Cleaning and Transformation
#
# From the full dataset we extracted a subset of the data types; a summary of their transformation and representation is displayed below.
#
# The only attribute with missing values are "shot clock time," since the shot clock does not turn on when the game clock is below 24 seconds. In these scenario, we use the game clock time for the shot clock time.
#
# Certain nominal values were transformed into binary values. A "WIN" value of 'W' is mapped to '1', and 'L' is mapped to '0'. Location is mapped from 'H' to '0' for home game, and "A" to '1' for away game. Shot made is represented as '0' for a "missed" shot and '1' for a "made" shot. Shot distance is discretized into three zones, called "SHOT_DIST_ZONE." Shot clock time is also discretized into 3 ranges, called "SHOT_CLOCK_PERIOD."
#
# **Attribute**|**Attribute Type**|**Representation**|**Meaning**
# :-----:|:-----:|:-----:|:-----:
# GAME\_ID|Nominal|Integer| Unique ID for a game
# LOCATION|Nominal|Binary|0 for home, 1 for away
# W|Nominal|Binary|0 for loss, 1 for win
# SHOT\_NUMBER|Nominal|Integer|Player's shot per game
# PERIOD|Ordinal|Integer|Period during a game
# GAME\_CLOCK|Ratio|Date-Time|Minutes and seconds left in game
# SHOT\_CLOCK|Ratio|Float|Seconds left in game
# SHOT\_CLOCK\_PERIOD|Nominal|Integer|0: 24-17 s, 1: 16-9 s, 2: 8-0 s
# DRIBBLES|Ordinal|Integer|Number of dribbles taken before shot
# TOUCH\_TIME|Ratio|Float|Seconds player possessed the ball before taking the shot
# SHOT\_DIST|Ratio|Float|Distance from basket where shot was taken
# SHOT\_DIST\_RANGE|Nominal|Integer|0: 0-15 ft, 1: 15-23.75 ft, 2: 23.75+ ft
# PTS\_TYPE|Ordinal|Integer|Number of points scored if made
# SHOT\_RESULT|Nominal|Binary|0 for missed basket, 1 for made basket
# CLOSE\_DEF\_DIST|Ratio|Float|Distance closest defender was from player

# %%
print(df.dtypes)
# Out:
# GAME_ID                         int64
# MATCHUP                        object
# LOCATION                       object
# W                              object
# FINAL_MARGIN                    int64
# SHOT_NUMBER                     int64
# PERIOD                          int64
# GAME_CLOCK                     object
# SHOT_CLOCK                    float64
# DRIBBLES                        int64
# TOUCH_TIME                    float64
# SHOT_DIST                     float64
# PTS_TYPE                        int64
# SHOT_RESULT                    object
# CLOSEST_DEFENDER               object
# CLOSEST_DEFENDER_PLAYER_ID      int64
# CLOSE_DEF_DIST                float64
# FGM                             int64
# PTS                             int64
# player_name                    object
# player_id                       int64
# dtype: object

# %%
pd.isnull(df['SHOT_CLOCK']).sum()
# Out:
# 5567

# %%
df.count()
# Out:
# GAME_ID                       128069
# MATCHUP                       128069
# LOCATION                      128069
# W                             128069
# FINAL_MARGIN                  128069
# SHOT_NUMBER                   128069
# PERIOD                        128069
# GAME_CLOCK                    128069
# SHOT_CLOCK                    122502
# DRIBBLES                      128069
# TOUCH_TIME                    128069
# SHOT_DIST                     128069
# PTS_TYPE                      128069
# SHOT_RESULT                   128069
# CLOSEST_DEFENDER              128069
# CLOSEST_DEFENDER_PLAYER_ID    128069
# CLOSE_DEF_DIST                128069
# FGM                           128069
# PTS                           128069
# player_name                   128069
# player_id                     128069
# dtype: int64

# %%
df[pd.isnull(df.SHOT_CLOCK)]
# Out:
#          GAME_ID                     MATCHUP LOCATION  W  FINAL_MARGIN  \
# 2       21400899    MAR 04, 2015 - CHA @ BKN        A  W            24
# 24      21400845    FEB 25, 2015 - CHA @ CHI        A  W            12
# 54      21400768  FEB 08, 2015 - CHA vs. IND        H  L            -1
# 76      21400742  FEB 05, 2015 - CHA vs. WAS        H  W             7
# 129     21400611  JAN 19, 2015 - CHA vs. MIN        H  W            25
# 134     21400611  JAN 19, 2015 - CHA vs. MIN        H  W            25
# 141     21400600  JAN 17, 2015 - CHA vs. IND        H  W             9
# 145     21400600  JAN 17, 2015 - CHA vs. IND        H  W             9
# 184     21400478    DEC 31, 2014 - CHA @ HOU        A  L           -19
# 204     21400423    DEC 23, 2014 - CHA @ MIL        A  W             7
# 247     21400263  DEC 03, 2014 - CHA vs. CHI        H  L            -7
# 250     21400263  DEC 03, 2014 - CHA vs. CHI        H  L            -7
# 299     21400195    NOV 23, 2014 - CHA @ MIA        A  L            -1
# 310     21400160    NOV 19, 2014 - CHA @ IND        A  L            -2
# 349     21400071  NOV 07, 2014 - CHA vs. ATL        H  W             3
# 453     21400237    NOV 29, 2014 - CHA @ ATL        A  L           -30
# 582     21400827    FEB 22, 2015 - CHA @ DAL        A  L           -11
# 600     21400816  FEB 21, 2015 - CHA vs. OKC        H  L            -7
# 623     21400768  FEB 08, 2015 - CHA vs. IND        H  L            -1
# 888     21400355    DEC 15, 2014 - CHA @ CLE        A  L            -9
# 975     21400237    NOV 29, 2014 - CHA @ ATL        A  L           -30
# 1043    21400195    NOV 23, 2014 - CHA @ MIA        A  L            -1
# 1157    21400097    NOV 09, 2014 - CHA @ LAL        A  L           -15
# 1366    21400713    JAN 31, 2015 - CHA @ DEN        A  W            18
# 1541    21400224  NOV 28, 2014 - CHA vs. GSW        H  L            -5
# 1542    21400224  NOV 28, 2014 - CHA vs. GSW        H  L            -5
# 1555    21400198  NOV 24, 2014 - CHA vs. LAC        H  L           -21
# 1669    21400888  MAR 02, 2015 - MIN vs. LAC        H  L            -5
# 1670    21400888  MAR 02, 2015 - MIN vs. LAC        H  L            -5
# 1678    21400873  FEB 28, 2015 - MIN vs. MEM        H  L            -4
# ...          ...                         ...      ... ..           ...
# 127678  21400605  JAN 17, 2015 - BKN vs. WAS        H  L            -9
# 127685  21400590    JAN 16, 2015 - BKN @ WAS        A  W            22
# 127703  21400576  JAN 14, 2015 - BKN vs. MEM        H  L           -11
# 127718  21400564  JAN 12, 2015 - BKN vs. HOU        H  L           -14
# 127730  21400551    JAN 10, 2015 - BKN @ DET        A  L            -5
# 127735  21400551    JAN 10, 2015 - BKN @ DET        A  L            -5
# 127736  21400551    JAN 10, 2015 - BKN @ DET        A  L            -5
# 127758  21400527  JAN 07, 2015 - BKN vs. BOS        H  L            -8
# 127765  21400511  JAN 05, 2015 - BKN vs. DAL        H  L            -8
# 127783  21400505    JAN 04, 2015 - BKN @ MIA        A  L            -4
# 127831  21400432    DEC 26, 2014 - BKN @ BOS        A  W             2
# 127891  21400364  DEC 16, 2014 - BKN vs. MIA        H  L            -4
# 127892  21400341    DEC 13, 2014 - BKN @ CHA        A  W            27
# 127905  21400332  DEC 12, 2014 - BKN vs. PHI        H  W            18
# 127909  21400320    DEC 10, 2014 - BKN @ CHI        A  L           -25
# 127913  21400320    DEC 10, 2014 - BKN @ CHI        A  L           -25
# 127927  21400280  DEC 05, 2014 - BKN vs. ATL        H  L           -23
# 127933  21400266  DEC 03, 2014 - BKN vs. SAS        H  W             2
# 127940  21400256    DEC 02, 2014 - BKN @ NYK        A  W             5
# 127941  21400256    DEC 02, 2014 - BKN @ NYK        A  W             5
# 127956  21400242  NOV 30, 2014 - BKN vs. CHI        H  L           -18
# 127960  21400213    NOV 26, 2014 - BKN @ PHI        A  W             8
# 127965  21400213    NOV 26, 2014 - BKN @ PHI        A  W             8
# 127967  21400191    NOV 22, 2014 - BKN @ SAS        A  L           -12
# 127996  21400164  NOV 19, 2014 - BKN vs. MIL        H  L            -4
# 128008  21400138    NOV 15, 2014 - BKN @ POR        A  L           -10
# 128017  21400138    NOV 15, 2014 - BKN @ POR        A  L           -10
# 128018  21400121    NOV 13, 2014 - BKN @ GSW        A  L            -8
# 128051  21400044  NOV 03, 2014 - BKN vs. OKC        H  W            31
# 128068  21400006    OCT 29, 2014 - BKN @ BOS        A  L           -16
#
#         SHOT_NUMBER  PERIOD GAME_CLOCK  SHOT_CLOCK  DRIBBLES    ...     \
# 2                 3       1       0:00         NaN         3    ...
# 24                6       2       0:04         NaN         0    ...
# 54               14       4       0:01         NaN         5    ...
# 76               10       3       0:01         NaN         2    ...
# 129               7       2       0:02         NaN         5    ...
# 134              12       3       0:03         NaN         2    ...
# 141               7       2       0:03         NaN         2    ...
# 145              11       3       0:01         NaN         6    ...
# 184               7       4       0:13         NaN         3    ...
# 204               1       1       0:01         NaN         2    ...
# 247               1       1       0:01         NaN         4    ...
# 250               4       2       0:06         NaN        20    ...
# 299               2       1       0:00         NaN         0    ...
# 310               3       1       0:04         NaN         0    ...
# 349               1       1       0:02         NaN         7    ...
# 453               1       1       0:03         NaN         0    ...
# 582              16       4       0:08         NaN         2    ...
# 600              18       4       0:06         NaN         0    ...
# 623               9       2       0:02         NaN         1    ...
# 888              13       4       0:17         NaN         0    ...
# 975               7       2       0:01         NaN         0    ...
# 1043             17       4       0:02         NaN         0    ...
# 1157             12       2       0:08         NaN         0    ...
# 1366              8       1       0:06         NaN         0    ...
# 1541              7       4       0:08         NaN         0    ...
# 1542              8       4       0:07         NaN         0    ...
# 1555              3       1       0:23         NaN         0    ...
# 1669             16       4       0:12         NaN         2    ...
# 1670             17       4       0:04         NaN         1    ...
# 1678              8       4       0:02         NaN         2    ...
# ...             ...     ...        ...         ...       ...    ...
# 127678           18       4       0:03         NaN         8    ...
# 127685            7       2       0:02         NaN        23    ...
# 127703            7       2       0:00         NaN         3    ...
# 127718           10       2       0:03         NaN        12    ...
# 127730            6       2       0:00         NaN         3    ...
# 127735           11       4       0:12         NaN         1    ...
# 127736           12       4       0:01         NaN         2    ...
# 127758           13       4       0:09         NaN         2    ...
# 127765            7       2       0:00         NaN         0    ...
# 127783            9       4       0:07         NaN         2    ...
# 127831            4       1       0:03         NaN         5    ...
# 127891            6       4       0:08         NaN         2    ...
# 127892            1       1       0:01         NaN         4    ...
# 127905            5       3       0:00         NaN         1    ...
# 127909            1       1       0:01         NaN         1    ...
# 127913            5       2       0:03         NaN        17    ...
# 127927            7       3       0:05         NaN         8    ...
# 127933            6       3       0:00         NaN         1    ...
# 127940            3       2       0:05         NaN         0    ...
# 127941            4       3       0:03         NaN         5    ...
# 127956           11       3       0:01         NaN         4    ...
# 127960            2       1       0:03         NaN        21    ...
# 127965            7       2       0:00         NaN         0    ...
# 127967            2       1       0:01         NaN         6    ...
# 127996            9       7       0:03         NaN         0    ...
# 128008            3       2       0:02         NaN         0    ...
# 128017           12       4       0:03         NaN         5    ...
# 128018            1       1       0:02         NaN        24    ...
# 128051            2       1       0:16         NaN         3    ...
# 128068            9       4       0:12         NaN         5    ...
#
#         SHOT_DIST  PTS_TYPE  SHOT_RESULT    CLOSEST_DEFENDER  \
# 2            10.1         2       missed   Bogdanovic, Bojan
# 24           25.2         3       missed       Butler, Jimmy
# 54           34.4         3       missed        Hill, George
# 76           13.1         2         made      Butler, Rasual
# 129          12.0         2       missed        Williams, Mo
# 134          17.9         2       missed       Daniels, Troy
# 141          10.4         2         made       Sloan, Donald
# 145          18.3         2       missed       Rudez, Damjan
# 184          27.1         3       missed      Canaan, Isaiah
# 204          32.9         3       missed       Dudley, Jared
# 247          41.6         3       missed       Brooks, Aaron
# 250           4.9         2       missed          Gasol, Pau
# 299          23.9         3       missed     Napier, Shabazz
# 310          24.8         3         made     Stuckey, Rodney
# 349          22.1         2       missed         Scott, Mike
# 453           3.2         2       missed        Brand, Elton
# 582           9.7         2       missed    Aminu, Al-Farouq
# 600          22.6         3         made       McGary, Mitch
# 623           8.2         2       missed        Hill, George
# 888          27.9         2         made       Marion, Shawn
# 975          23.7         3       missed        Teague, Jeff
# 1043          1.3         2       missed    Williams, Shawne
# 1157          3.2         2       missed     Johnson, Wesley
# 1366          0.9         2         made       McGee, JaVale
# 1541          1.1         2       missed     Green, Draymond
# 1542          5.3         2         made     Green, Draymond
# 1555          3.0         2         made      Hawes, Spencer
# 1669         24.6         3       missed      Rivers, Austin
# 1670         26.4         3       missed      Jones, Dahntay
# 1678         25.2         3       missed       Lee, Courtney
# ...           ...       ...          ...                 ...
# 127678        6.8         2       missed     Seraphin, Kevin
# 127685        8.3         2         made       Miller, Andre
# 127703       25.9         3       missed      Randolph, Zach
# 127718       24.0         3       missed        Dorsey, Joey
# 127730       41.9         3       missed   Jennings, Brandon
# 127735       24.0         3       missed   Jennings, Brandon
# 127736        4.0         2         made   Jennings, Brandon
# 127758        3.6         2         made        Turner, Evan
# 127765       31.8         3       missed      Nowitzki, Dirk
# 127783       11.0         2         made     Chalmers, Mario
# 127831       25.0         3         made     Wright, Brandan
# 127891        7.0         2       missed     Chalmers, Mario
# 127892        9.3         2         made      Roberts, Brian
# 127905       35.8         3       missed        Wroten, Tony
# 127909       39.2         3       missed       Hinrich, Kirk
# 127913        2.3         2       missed          Gasol, Pau
# 127927       14.4         2       missed       Mack, Shelvin
# 127933       32.1         3       missed    Belinelli, Marco
# 127940       23.9         3       missed   Hardaway Jr., Tim
# 127941       17.5         2         made       Larkin, Shane
# 127956       36.6         3       missed      Moore, E'Twaun
# 127960       23.8         3       missed     Davies, Brandon
# 127965       36.3         3       missed    Thompson, Hollis
# 127967       15.5         2         made        Baynes, Aron
# 127996       26.7         3       missed          Mayo, O.J.
# 128008       20.6         3       missed        Blake, Steve
# 128017        8.5         2       missed     Lillard, Damian
# 128018        4.8         2         made    Barbosa, Leandro
# 128051        2.6         2         made  Telfair, Sebastian
# 128068        5.1         2         made      Bradley, Avery
#
#        CLOSEST_DEFENDER_PLAYER_ID  CLOSE_DEF_DIST  FGM  PTS      player_name  \
# 2                          202711             0.9    0    0    brian roberts
# 24                         202710             3.6    0    0    brian roberts
# 54                         201588             3.6    0    0    brian roberts
# 76                           2446             2.5    1    2    brian roberts
# 129                          2590             4.0    0    0    brian roberts
# 134                        203584             2.7    0    0    brian roberts
# 141                        202388             2.7    1    2    brian roberts
# 145                        204014             2.2    0    0    brian roberts
# 184                        203477             5.6    0    0    brian roberts
# 204                        201162             4.1    0    0    brian roberts
# 247                        201166             6.0    0    0    brian roberts
# 250                          2200             3.5    0    0    brian roberts
# 299                        203894             3.6    0    0    brian roberts
# 310                        201155             4.2    1    3    brian roberts
# 349                        203118             3.8    0    0    brian roberts
# 453                          1882             1.9    0    0  bismack biyombo
# 582                        202329             2.5    0    0     al jefferson
# 600                        203956             5.9    1    3     al jefferson
# 623                        201588             2.5    0    0     al jefferson
# 888                          1890             7.0    1    2     al jefferson
# 975                        201952             6.8    0    0     al jefferson
# 1043                       200761             1.3    0    0     al jefferson
# 1157                       202325             1.9    0    0     al jefferson
# 1366                       201580             4.1    1    2      cody zeller
# 1541                       203110             0.5    0    0      cody zeller
# 1542                       203110             2.3    1    2      cody zeller
# 1555                       201150             8.0    1    2      cody zeller
# 1669                       203085             1.2    0    0        gary neal
# 1670                         2563             2.9    0    0        gary neal
# 1678                       201584             2.1    0    0        gary neal
# ...                           ...             ...  ...  ...              ...
# 127678                     202338             1.8    0    0     jarrett jack
# 127685                       1889             3.8    1    2     jarrett jack
# 127703                       2216             2.4    0    0     jarrett jack
# 127718                     201595             3.9    0    0     jarrett jack
# 127730                     201943             3.7    0    0     jarrett jack
# 127735                     201943             8.0    0    0     jarrett jack
# 127736                     201943             6.1    1    2     jarrett jack
# 127758                     202323             3.1    1    2     jarrett jack
# 127765                       1717             5.2    0    0     jarrett jack
# 127783                     201596             3.6    1    2     jarrett jack
# 127831                     201148             5.4    1    3     jarrett jack
# 127891                     201596             3.1    0    0     jarrett jack
# 127892                     203148             1.8    1    2     jarrett jack
# 127905                     203100             6.7    0    0     jarrett jack
# 127909                       2550             2.6    0    0     jarrett jack
# 127913                       2200             2.0    0    0     jarrett jack
# 127927                     202714             4.3    0    0     jarrett jack
# 127933                     201158             4.4    0    0     jarrett jack
# 127940                     203501             3.5    0    0     jarrett jack
# 127941                     203499             3.2    1    2     jarrett jack
# 127956                     202734             4.0    0    0     jarrett jack
# 127960                     203561             2.9    0    0     jarrett jack
# 127965                     203138             8.5    0    0     jarrett jack
# 127967                     203382             4.7    1    2     jarrett jack
# 127996                     201564             1.9    0    0     jarrett jack
# 128008                       2581             1.7    0    0     jarrett jack
# 128017                     203081             4.5    0    0     jarrett jack
# 128018                       2571             5.0    1    2     jarrett jack
# 128051                       2742             5.4    1    2     jarrett jack
# 128068                     202340             2.3    1    2     jarrett jack
#
#        player_id
# 2         203148
# 24        203148
# 54        203148
# 76        203148
# 129       203148
# 134       203148
# 141       203148
# 145       203148
# 184       203148
# 204       203148
# 247       203148
# 250       203148
# 299       203148
# 310       203148
# 349       203148
# 453       202687
# 582         2744
# 600         2744
# 623         2744
# 888         2744
# 975         2744
# 1043        2744
# 1157        2744
# 1366      203469
# 1541      203469
# 1542      203469
# 1555      203469
# 1669      202390
# 1670      202390
# 1678      202390
# ...          ...
# 127678    101127
# 127685    101127
# 127703    101127
# 127718    101127
# 127730    101127
# 127735    101127
# 127736    101127
# 127758    101127
# 127765    101127
# 127783    101127
# 127831    101127
# 127891    101127
# 127892    101127
# 127905    101127
# 127909    101127
# 127913    101127
# 127927    101127
# 127933    101127
# 127940    101127
# 127941    101127
# 127956    101127
# 127960    101127
# 127965    101127
# 127967    101127
# 127996    101127
# 128008    101127
# 128017    101127
# 128018    101127
# 128051    101127
# 128068    101127
#
# [5567 rows x 21 columns]

# %%
max(df.GAME_CLOCK)
# Out:
# '9:59'

# %%
df.TOUCH_TIME.tail()
# Out:
# 128064    6.2
# 128065    5.2
# 128066    4.2
# 128067    4.5
# 128068    4.7
# Name: TOUCH_TIME, dtype: float64
